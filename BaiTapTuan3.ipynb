# %% [markdown]
# ##### W3A2:

# %%
a = int(input("Nhập số thứ nhất: "))
b = int(input("Nhập số thứ hai: "))
print(f"Trước khi hoán đổi: a = {a}, b = {b}")
a = a ^ b
b = a ^ b
a = a ^ b
print(f"Sau khi hoán đổi: a = {a}, b = {b}")
# Out:
# Trước khi hoán đổi: a = 3, b = 8
# Sau khi hoán đổi: a = 8, b = 3

# %% [markdown]
# ##### W3A3:

# %%
n = int(input())
if n > 0 and (n & (n - 1)) == 0:
    print(n, "là lũy thừa của 2")
else:
    print(n, "không phải lũy thừa của 2")
# Out:
# 4 là lũy thừa của 2

# %% [markdown]
# ##### W3A4:

# %%
m = int(input())
n = int(input())
if n == 0:
    print("Lỗi: Không thể chia cho 0")
else:
    ketqua = m // n
    print(ketqua)
# Out:
# 1

# %% [markdown]
# ##### W3A5:

# %%
import math
m = int(input())
n = int(input())
if n == 0:
    print("Lỗi: Không thể chia cho 0")
else:
    ketqua = math.ceil(m / n)
    print(ketqua)
# Out:
# 3

# %% [markdown]
# ##### W3A6:

# %%
x = int(input())
if x % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# ##### W3A7:

# %%
a = int(input())
b = int(input())
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# ##### W3A8:

# %%
a = input()
b = input()
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ##### W3A9:

# %%
a = int(input())
b = int(input())
c = int(input())
if a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# ##### W3A10:

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
max = a
if b > max:
    max = b
if c > max:
    max = c
if d > max:
    max = d
print(max)
# Out:
# 7

# %% [markdown]
# ##### W3A91:

# %%
a = int(input())
b = int(input())
c = int(input())
if a + b > c and a + c > b and b + c > a:
    if a == b == c:
        print("Tam giác đều")
    elif a == b or b == c or a == c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# Không phải tam giác

# %% [markdown]
# ##### W3A12:

# %%
n = int(input())
if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# ##### W3A14:

# %%
a = float(input())
b = float(input())
if a == 0:
    if b == 0:
        print(f"Phương trình {a}x + {b} = 0 có vô số nghiệm")
    else:
        print(f"Phương trình {a}x + {b} = 0 vô nghiệm")
else:
    x = -b / a
    print(f"Nghiệm của phương trình {a}x + {b} = 0 là x = {x}")
# Out:
# Nghiệm của phương trình 4.0x + 6.0 = 0 là x = -1.5

# %% [markdown]
# ##### W3A15:

# %%
x = float(input())
if x >= 8.0:
    print("Giỏi")
elif x >= 6.5:
    print("Khá")
elif x >= 5.0:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Giỏi

# %% [markdown]
# ##### W3A16:

# %%
n = float(input())
tron_xuong = int(n) if n >= 0 else int(n) - (n != int(n))
tron_len = int(n) if n <= 0 or n == int(n) else int(n) + 1
if n >= 0:
    tron_gan = int(n + 0.5)
else:
    tron_gan = int(n - 0.5)
print(tron_xuong, tron_len, tron_gan)
# Out:
# 385 386 386

# %% [markdown]
# ##### W3A17:

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if a == 0:
    print("Không phải cấp số nhân")
else:
    if b % a == 0:
        q = b // a
        if c == b * q and d == c * q:
            print("Là cấp số nhân")
        else:
            print("Không phải cấp số nhân")
    else:
        print("Không phải cấp số nhân")
# Out:
# Là cấp số nhân
